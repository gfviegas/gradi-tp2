# %%
# Importando todas bibliotecas necessárias

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import psycopg2
from collections import defaultdict

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Fazendo a conexão com o banco de dados

# %%
conn = psycopg2.connect("dbname='warehouse' user='admin' host='datawarehouse' password='admin123'")
cur = conn.cursor()
# conn.autocommit = True

# %% [markdown]
# ## Pegando no banco de dados quais os anos dos modelos dos veículos na base para categorizar em veículos novos (50% mais novos) e antigos.

# %%
cur.execute("SELECT DISTINCT EXTRACT(YEAR FROM data_compra) as ano FROM veiculo ORDER BY ano ASC")
anos_veiculos = list(map(lambda v: int(v[0]), cur.fetchall()))

indice_metade = int(len(anos_veiculos) / 2)
anos_veiculos_novos = anos_veiculos[indice_metade:]
anos_veiculos_antigos = anos_veiculos[:indice_metade]

print('Anos dos veículos: {}'.format(anos_veiculos))
print('Anos de veículos novos: {}'.format(anos_veiculos_novos))
print('Anos de veículos antigos: {}'.format(anos_veiculos_antigos))
# Out:
# Anos dos veículos: [2013, 2014, 2015, 2016, 2017, 2018]
# Anos de veículos novos: [2016, 2017, 2018]
# Anos de veículos antigos: [2013, 2014, 2015]

# %% [markdown]
# ## Buscando todos os sinistros

# %%
rows = []
columns = []

# Como o select retornará MUITOS dados, vamos pegar em batches.
with conn.cursor(name='large') as cursor:
    cursor.itersize = 20000

    query = """SELECT
                an.ano,
                EXTRACT(YEAR FROM cl.data_nasc) AS ano_cliente,
                EXTRACT(YEAR FROM ve.data_compra) AS ano_veiculo,
                cl.regiao AS regiao_cliente,
                cl.estado AS estado_cliente,
                cl.cidade AS cidade_cliente,
                cl.sexo AS sexo_cliente,
                ve.cor AS cor_veiculo,
                ve.valor_compra AS valor_veiculo,
                ve.nome_montadora AS montadora_veiculo,
                ve.nome_modelo AS modelo_veiculo,
                ve.pais_origem_montadora AS pais_montadora_veiculo
            FROM sinistro si
            INNER JOIN cliente cl ON si.cliente_id = cl.cliente_id
            INNER JOIN veiculo ve ON si.veiculo_id = ve.veiculo_id
            INNER JOIN ano an ON si.ano_id = an.ano_id
            -- WHERE si.ano_id = (SELECT ano_id FROM ano WHERE ano = (SELECT MAX(ano) from ANO LIMIT 1) LIMIT 1);
            """
    cursor.execute(query)
    for row in cursor:
        rows.append(row)
        
    for col in cursor.description:
        columns.append(col[0])
    
print('{} linhas recuperadas'.format(len(rows)))
# Out:
# 819692 linhas recuperadas

# %%
df = pd.DataFrame(rows, columns=columns)
df
# Out:
#          ano  ano_cliente  ano_veiculo regiao_cliente estado_cliente  \
# 0       2018       1988.0       2015.0        sudeste             SP
# 1       2017       1980.0       2016.0       nordeste             PE
# 2       2015       1980.0       2013.0       nordeste             PE
# 3       2018       1980.0       2013.0       nordeste             PE
# 4       2013       1962.0       2013.0            sul             SC
# ...      ...          ...          ...            ...            ...
# 819687  2017       1986.0       2015.0       nordeste             PE
# 819688  2013       1986.0       2013.0       nordeste             PE
# 819689  2016       1986.0       2013.0       nordeste             PE
# 819690  2018       1986.0       2013.0       nordeste             PE
# 819691  2018       1946.0       2018.0       nordeste             PE
#
#        cidade_cliente sexo_cliente cor_veiculo  valor_veiculo  \
# 0            campinas            F       preto        53028.0
# 1         belo jardim            M        azul        49019.0
# 2         belo jardim            M      branco        82015.0
# 3         belo jardim            M      branco        82015.0
# 4            palmitos            M       preto        66006.0
# ...               ...          ...         ...            ...
# 819687      petrolina            F    vermelho        83021.0
# 819688      petrolina            F       prata        66030.0
# 819689      petrolina            F       prata        66030.0
# 819690      petrolina            F       prata        66030.0
# 819691         olinda            M    vermelho        87037.0
#
#        montadora_veiculo modelo_veiculo pais_montadora_veiculo
# 0                   fiat            uno                 Italia
# 1             volkswagen            gol               Alemanha
# 2             volkswagen           polo               Alemanha
# 3             volkswagen           polo               Alemanha
# 4                  honda           city                  Japao
# ...                  ...            ...                    ...
# 819687             honda            fit                  Japao
# 819688             honda           city                  Japao
# 819689             honda           city                  Japao
# 819690             honda           city                  Japao
# 819691        volkswagen           polo               Alemanha
#
# [819692 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819692 entries, 0 to 819691
# Data columns (total 12 columns):
# ano                       819692 non-null int64
# ano_cliente               819692 non-null float64
# ano_veiculo               819692 non-null float64
# regiao_cliente            819692 non-null object
# estado_cliente            819692 non-null object
# cidade_cliente            819692 non-null object
# sexo_cliente              819692 non-null object
# cor_veiculo               819692 non-null object
# valor_veiculo             819692 non-null float64
# montadora_veiculo         819692 non-null object
# modelo_veiculo            819692 non-null object
# pais_montadora_veiculo    819692 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 75.0+ MB

# %% [markdown]
# # Fazendo a limpeza no dataframe, convertendo tipos, etc

# %%
df[['ano_cliente', 'ano_veiculo']] = df[['ano_cliente', 'ano_veiculo']].astype(int)

# %%
df[['ano_cliente', 'ano_veiculo', 'valor_veiculo']].describe()
# Out:
#          ano_cliente    ano_veiculo  valor_veiculo
# count  819692.000000  819692.000000  819692.000000
# mean     1975.868998    2014.688570   78734.241962
# std        16.144379       1.693449   43856.754575
# min      1940.000000    2013.000000   41000.000000
# 25%      1968.000000    2013.000000   48007.000000
# 50%      1979.000000    2014.000000   69045.000000
# 75%      1988.000000    2016.000000   86044.000000
# max      1999.000000    2018.000000  318049.000000

# %% [markdown]
# # Verificando correlação

# %%
df_grouped = df.groupby(['ano_cliente', 'ano_veiculo', 'valor_veiculo']).size().reset_index()
df_grouped.rename(columns={ df_grouped.columns[3]: "quantidade_sinistros" }, inplace = True)
df_grouped
# Out:
#         ano_cliente  ano_veiculo  valor_veiculo  quantidade_sinistros
# 0              1940         2013        41000.0                    21
# 1              1940         2013        41001.0                    12
# 2              1940         2013        41002.0                     4
# 3              1940         2013        41003.0                    14
# 4              1940         2013        41004.0                    13
# ...             ...          ...            ...                   ...
# 226847         1999         2018       318033.0                     1
# 226848         1999         2018       318038.0                     1
# 226849         1999         2018       318040.0                     1
# 226850         1999         2018       318045.0                     1
# 226851         1999         2018       318047.0                     1
#
# [226852 rows x 4 columns]

# %%
cor = df_grouped.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Greens)
plt.show()

# %%
df_grouped2 = df.groupby(['modelo_veiculo', 'ano_cliente', 'ano_veiculo', 'valor_veiculo']).size().reset_index()
df_grouped2.rename(columns={ df_grouped2.columns[4]: "quantidade_sinistros" }, inplace = True)
df_grouped2
# Out:
#        modelo_veiculo  ano_cliente  ano_veiculo  valor_veiculo  \
# 0                argo         1940         2013        76000.0
# 1                argo         1940         2013        76001.0
# 2                argo         1940         2013        76003.0
# 3                argo         1940         2013        76004.0
# 4                argo         1940         2013        76005.0
# ...               ...          ...          ...            ...
# 259305            wrv         1999         2018        74038.0
# 259306            wrv         1999         2018        74040.0
# 259307            wrv         1999         2018        74041.0
# 259308            wrv         1999         2018        74044.0
# 259309            wrv         1999         2018        74045.0
#
#         quantidade_sinistros
# 0                          2
# 1                          2
# 2                          3
# 3                          4
# 4                          1
# ...                      ...
# 259305                     1
# 259306                     1
# 259307                     1
# 259308                     1
# 259309                     1
#
# [259310 rows x 5 columns]

# %%
cor = df_grouped2.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Blues)
plt.show()

# %%
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
sns.pairplot(df_grouped, hue='ano', diag_kind='hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ano'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-72d1b6229fec> in <module>
# ----> 1 sns.pairplot(df_grouped, hue='ano', diag_kind='hist')
#
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# /usr/local/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, height, aspect, despine, dropna, size)
#    1288                                       index=data.index)
#    1289         else:
# -> 1290             hue_names = utils.categorical_order(data[hue], hue_order)
#    1291             if dropna:
#    1292                 # Filter NA from the list of unique hue names
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ano'

# %% [markdown]
# ## As correlações estão claramente fracas, mas precisamos agrupar os dados em clusters pra fazer sentidos.
#
# Por exemplo, podemos dividir os clientes em grupos de motoristas experientes ou não, ou os modelos de veículos de antigos e novos

# %%
kmeans = KMeans(n_clusters=2).fit(df_grouped[['ano_veiculo']])
df_grouped.loc[:,'grupo_ano_veiculo'] = kmeans.labels_
centroids = kmeans.cluster_centers_
print('Centroídes: {}'.format(centroids))

kmeans = KMeans(n_clusters=2).fit(df_grouped[['ano_cliente']])
df_grouped.loc[:,'grupo_ano_cliente'] = kmeans.labels_
centroids = kmeans.cluster_centers_
print('Centroídes: {}'.format(centroids))
df_grouped
# Out:
# Centroídes: [[2013.87297756]
#  [2016.91165706]]
# Centroídes: [[1983.96322218]
#  [1953.16802405]]
#         ano_cliente  ano_veiculo  valor_veiculo  quantidade_sinistros  \
# 0              1940         2013        41000.0                    21
# 1              1940         2013        41001.0                    12
# 2              1940         2013        41002.0                     4
# 3              1940         2013        41003.0                    14
# 4              1940         2013        41004.0                    13
# ...             ...          ...            ...                   ...
# 226847         1999         2018       318033.0                     1
# 226848         1999         2018       318038.0                     1
# 226849         1999         2018       318040.0                     1
# 226850         1999         2018       318045.0                     1
# 226851         1999         2018       318047.0                     1
#
#         grupo_ano_veiculo  grupo_ano_cliente
# 0                       0                  1
# 1                       0                  1
# 2                       0                  1
# 3                       0                  1
# 4                       0                  1
# ...                   ...                ...
# 226847                  1                  0
# 226848                  1                  0
# 226849                  1                  0
# 226850                  1                  0
# 226851                  1                  0
#
# [226852 rows x 6 columns]

# %%
cor = df_grouped[['quantidade_sinistros', 'grupo_ano_veiculo', 'grupo_ano_cliente']].corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Greens)
plt.show()

# %% [markdown]
# Mesmo assim, a correlação é baixa.

# %% [markdown]
# # Vamos também clusterizar a quantidade de sinistros para verificar se existe uma correlação com as demais colunas

# %%
kmeans = KMeans(n_clusters=5).fit(df_grouped[['quantidade_sinistros']])
df_grouped.loc[:,'grupo_quantidade_sinistros'] = kmeans.labels_
centroids = kmeans.cluster_centers_
print('Centroídes: {}'.format(centroids))
df_grouped
# Out:
# Centroídes: [[ 4.05161414]
#  [14.94544149]
#  [ 1.3851813 ]
#  [ 8.44387079]
#  [27.49034982]]
#         ano_cliente  ano_veiculo  valor_veiculo  quantidade_sinistros  \
# 0              1940         2013        41000.0                    21
# 1              1940         2013        41001.0                    12
# 2              1940         2013        41002.0                     4
# 3              1940         2013        41003.0                    14
# 4              1940         2013        41004.0                    13
# ...             ...          ...            ...                   ...
# 226847         1999         2018       318033.0                     1
# 226848         1999         2018       318038.0                     1
# 226849         1999         2018       318040.0                     1
# 226850         1999         2018       318045.0                     1
# 226851         1999         2018       318047.0                     1
#
#         grupo_ano_veiculo  grupo_ano_cliente  grupo_quantidade_sinistros
# 0                       0                  1                           1
# 1                       0                  1                           1
# 2                       0                  1                           0
# 3                       0                  1                           1
# 4                       0                  1                           1
# ...                   ...                ...                         ...
# 226847                  1                  0                           2
# 226848                  1                  0                           2
# 226849                  1                  0                           2
# 226850                  1                  0                           2
# 226851                  1                  0                           2
#
# [226852 rows x 7 columns]

# %%
df2 = df_grouped[['grupo_quantidade_sinistros', 'ano_veiculo', 'ano_cliente', 'valor_veiculo']]
df2.groupby(['grupo_quantidade_sinistros']).size()
# Out:
# grupo_quantidade_sinistros
# 0     72887
# 1      8358
# 2    122062
# 3     21887
# 4      1658
# dtype: int64

# %%
sns.pairplot(df2, vars=['ano_veiculo', 'ano_cliente', 'valor_veiculo'], hue='grupo_quantidade_sinistros', kind='reg')

# %%
# v = df.drop('ano', axis=1).columns
# sns.pairplot(df, vars=v, hue='ano', diag_kind='hist')

# %% [markdown]
# # ---------------------------------
# # Predizendo sinistros
#
# A partir dos sinistros que ocorreram no último ano, vamos criar uma coluna no df pra pegar todos os clientes e modelos que tiveram sinistro no último ano e os que não tiveram

# %%
df3 = df.copy()
ultimo_ano = df.ano.max()

df3['sinistro_recente'] = df3.apply(lambda row: row.ano == ultimo_ano, axis=1)
df3 = df3.drop('ano', axis=1)
df3
# Out:
#         ano_cliente  ano_veiculo regiao_cliente estado_cliente cidade_cliente  \
# 0              1988         2015        sudeste             SP       campinas
# 1              1980         2016       nordeste             PE    belo jardim
# 2              1980         2013       nordeste             PE    belo jardim
# 3              1980         2013       nordeste             PE    belo jardim
# 4              1962         2013            sul             SC       palmitos
# ...             ...          ...            ...            ...            ...
# 819687         1986         2015       nordeste             PE      petrolina
# 819688         1986         2013       nordeste             PE      petrolina
# 819689         1986         2013       nordeste             PE      petrolina
# 819690         1986         2013       nordeste             PE      petrolina
# 819691         1946         2018       nordeste             PE         olinda
#
#        sexo_cliente cor_veiculo  valor_veiculo montadora_veiculo  \
# 0                 F       preto        53028.0              fiat
# 1                 M        azul        49019.0        volkswagen
# 2                 M      branco        82015.0        volkswagen
# 3                 M      branco        82015.0        volkswagen
# 4                 M       preto        66006.0             honda
# ...             ...         ...            ...               ...
# 819687            F    vermelho        83021.0             honda
# 819688            F       prata        66030.0             honda
# 819689            F       prata        66030.0             honda
# 819690            F       prata        66030.0             honda
# 819691            M    vermelho        87037.0        volkswagen
#
#        modelo_veiculo pais_montadora_veiculo  sinistro_recente
# 0                 uno                 Italia              True
# 1                 gol               Alemanha             False
# 2                polo               Alemanha             False
# 3                polo               Alemanha              True
# 4                city                  Japao             False
# ...               ...                    ...               ...
# 819687            fit                  Japao             False
# 819688           city                  Japao             False
# 819689           city                  Japao             False
# 819690           city                  Japao              True
# 819691           polo               Alemanha              True
#
# [819692 rows x 12 columns]

# %%
# Criando encoder pra colunas de string
d = defaultdict(LabelEncoder)
df3 = df3.apply(lambda x: d[x.name].fit_transform(x))

X = df3.drop(['sinistro_recente'], axis=1)
y = df3['sinistro_recente']

df3
# Out:
#         ano_cliente  ano_veiculo  regiao_cliente  estado_cliente  \
# 0                48            2               3               9
# 1                40            3               1               6
# 2                40            0               1               6
# 3                40            0               1               6
# 4                22            0               4               8
# ...             ...          ...             ...             ...
# 819687           46            2               1               6
# 819688           46            0               1               6
# 819689           46            0               1               6
# 819690           46            0               1               6
# 819691            6            5               1               6
#
#         cidade_cliente  sexo_cliente  cor_veiculo  valor_veiculo  \
# 0                   11             0            4            628
# 1                    5             1            0            419
# 2                    5             1            1           1865
# 3                    5             1            1           1865
# 4                   33             1            4           1056
# ...                ...           ...          ...            ...
# 819687              37             0            6           1921
# 819688              37             0            3           1080
# 819689              37             0            3           1080
# 819690              37             0            3           1080
# 819691              32             1            6           2137
#
#         montadora_veiculo  modelo_veiculo  pais_montadora_veiculo  \
# 0                       1              26                       2
# 1                       5              12                       0
# 2                       5              21                       0
# 3                       5              21                       0
# 4                       3               3                       3
# ...                   ...             ...                     ...
# 819687                  3               9                       3
# 819688                  3               3                       3
# 819689                  3               3                       3
# 819690                  3               3                       3
# 819691                  5              21                       0
#
#         sinistro_recente
# 0                      1
# 1                      0
# 2                      0
# 3                      1
# 4                      0
# ...                  ...
# 819687                 0
# 819688                 0
# 819689                 0
# 819690                 1
# 819691                 1
#
# [819692 rows x 12 columns]

# %%
# Dividindo os datasets pra treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)


# Escalando os dados pra obter melhores resultados
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Usando rede neural pra classificar a probabilidade de um cliente sofrer um sinistro ou não no último ano.
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=2000)
mlp.fit(X_train, y_train.values.ravel())

predictions = mlp.predict(X_test)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[108663   5315]
#  [ 34006  15955]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85    113978
#            1       0.75      0.32      0.45     49961
#
#     accuracy                           0.76    163939
#    macro avg       0.76      0.64      0.65    163939
# weighted avg       0.76      0.76      0.73    163939

# %%
# Usando ADABoost
from sklearn.ensemble import AdaBoostClassifier

classifier = AdaBoostClassifier(n_estimators=100, random_state=0)
classifier.fit(X_train, y_train.values.ravel())

predictions = classifier.predict(X_test)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[108867   5111]
#  [ 34232  15729]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85    113978
#            1       0.75      0.31      0.44     49961
#
#     accuracy                           0.76    163939
#    macro avg       0.76      0.63      0.65    163939
# weighted avg       0.76      0.76      0.72    163939

# %%
# Usando vetor de suporte / Modelo gradiente estocástico
from sklearn.linear_model import SGDClassifier

classifier = SGDClassifier(max_iter=1000, tol=1e-3)
classifier.fit(X_train, y_train.values.ravel())

predictions = classifier.predict(X_test)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[97739 16239]
#  [25589 24372]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82    113978
#            1       0.60      0.49      0.54     49961
#
#     accuracy                           0.74    163939
#    macro avg       0.70      0.67      0.68    163939
# weighted avg       0.73      0.74      0.74    163939

# %%
# Usando random forest
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
classifier.fit(X_train, y_train.values.ravel())

predictions = classifier.predict(X_test)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[113978      0]
#  [ 39402  10559]]
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85    113978
#            1       1.00      0.21      0.35     49961
#
#     accuracy                           0.76    163939
#    macro avg       0.87      0.61      0.60    163939
# weighted avg       0.82      0.76      0.70    163939

# %% [markdown]
# ### Será que os membros do grupo seriam clientes propícios a ter um sinistro? 🤔🤔🤔
#
# TODO

# %%
d
# Out:
# defaultdict(sklearn.preprocessing.label.LabelEncoder,
#             {'ano_cliente': LabelEncoder(),
#              'ano_veiculo': LabelEncoder(),
#              'regiao_cliente': LabelEncoder(),
#              'estado_cliente': LabelEncoder(),
#              'cidade_cliente': LabelEncoder(),
#              'sexo_cliente': LabelEncoder(),
#              'cor_veiculo': LabelEncoder(),
#              'valor_veiculo': LabelEncoder(),
#              'montadora_veiculo': LabelEncoder(),
#              'modelo_veiculo': LabelEncoder(),
#              'pais_montadora_veiculo': LabelEncoder(),
#              'sinistro_recente': LabelEncoder()})
